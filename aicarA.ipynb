# %% [markdown]
# AICAR 자율주행 자동차 --------------------------------------------------  <aicarA.ipynb>  2024-04-08
# 1. Raspberry Pi 에서 도로 이미지 압축한 ZIP 파일을 올려 놓습니다.
# 2. Colab 메뉴 -> 런타임 -> 런타임 유형변경 -> T4 GPU를 선택하고 저장합니다.
# 3. Colab 메뉴 -> 런타임 -> 모두 실행을 선택합니다.
# 4. *.pt 파일을 다운로드 합니다.

# %% [markdown]
# <STEP 1>이미지 파일 압축 풀기 - 실행 하기 전 압축파일(*.zip)을 올려 놓아야 합니다.

# %%
EPOCHS = None; learnRate = None                                                 # epochN = 300, learnRate = 0.0005/0.0010/0.0015/0.0020/0.0025
import glob
import zipfile
fileList = glob.glob('*.zip')
zip_ref = zipfile.ZipFile(fileList[0], 'r');
zip_ref.extractall()
zip_ref.close()
w = fileList[0].split('.'); project = w[-2]
print('프로젝트:',project)
# Out:
# 프로젝트: ympark_RnD

# %% [markdown]
# <STEP 2> 라이브러리 가져오기(Import)

# %%
import os
import sys
import random
import fnmatch
import pickle
import time
import numpy as np
import cv2                                                                      # Open Cv 영상처리 라이브러리
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary as summary
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline
from PIL import Image

print(f'Python Version:     {sys.version}')                                     # Python Version
print(f'OpenCV version:     {cv2.__version__}')                                  # Open CV version
print(f'Pytorch version:    {torch.__version__}')                               # Pytorch version
# Out:
# Python Version:     3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# OpenCV version:     4.12.0
# Pytorch version:    2.8.0+cu126

# %% [markdown]
# <STEP 3> 이미지 데이터 조향각 추출

# %%
with open(f'{project}/_{project}.pickle', 'rb') as f:                           # pickle 파일
    x_exam_Image = pickle.load(f)                                               # 시험(Test) 이미지 파일 이름 리스트
    x_valid_Image = pickle.load(f)                                              # 평가(Valid) 이미지 파일 이름 리스트
    x_train_Image = pickle.load(f)                                              # 훈련(Train) 이미지 파일 이름 리스트
    p = pickle.load(f)                                                          # 파라메터 리스트
if EPOCHS == None: EPOCHS = p[0]                                                # 학습회수
if learnRate == None: learnRate = p[1]                                          # 학습 비율 0.0005/0.0010/0.0015/0.0020/0.0025
#-------------------------------------------------------------------------------
y_exam_Angle=[]
y_valid_Angle=[]
y_train_Angle = []
for f in x_exam_Image:                                                          # 시험용 이미지 파일 이름에서 각도값
    y_exam_Angle.append(int(f[-7:-4]))
for f in x_valid_Image:                                                         # 평가용 이미지 파일 이름에서 각도값
    y_valid_Angle.append(int(f[-7:-4]))
for f in x_train_Image:                                                         # 훈련용 이미지 파일 이름에서 각도값
    y_train_Angle.append(int(f[-7:-4]))

print('학습 회수:',EPOCHS,)
print('학습 비율', learnRate)
print('시험 이미지 개수:',len(x_exam_Image))
print('평가 이미지 개수:',len(x_valid_Image))
print('훈련 이미지 개수:',len(x_train_Image))
# Out:
# 학습 회수: 300
# 학습 비율 0.001
# 시험 이미지 개수: 6
# 평가 이미지 개수: 98
# 훈련 이미지 개수: 399

# %% [markdown]
# <STEP 4> Nvidia CNN 모델 구성

# %%
# Pytorch device 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f'{device} is available')

# Nvidia CNN 모델 구성 ---------------------------------------------------------
class NvidiaModel(nn.Module):
    def __init__(self):
      super(NvidiaModel, self).__init__()

      # elu=Expenential Linear Unit, similar to leaky Relu
      # skipping 1st hiddel layer (nomralization layer), as we have normalized the data

      # Convolution Layers
      self.layer1 = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=24, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=24, out_channels=36, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=36, out_channels=48, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=48, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True),
        nn.Dropout(0.2),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True)
      )

      # Fully Connected Layers
      self.layer2 = nn.Sequential(
        # nn.Flatten(),
        nn.Dropout(0.2),
        nn.Linear(in_features=18 * 64, out_features=100),
        nn.ELU(inplace=True),
        nn.Linear(in_features=100, out_features=50),
        nn.ELU(inplace=True),
        nn.Linear(in_features=50, out_features=10),
        nn.ELU(inplace=True)
      )

      # Output Layer
      self.layer3 = nn.Sequential(
        nn.Linear(in_features=10, out_features=1)
      )

    def forward(self, x):
      x = self.layer1(x)
      x = x.view(x.shape[0], -1)
      x = self.layer2(x)
      x = self.layer3(x)

      return x
#-------------------------------------------------------------------------------
def imgPaths(fGroup):
    r = []
    for filename in fGroup:
        r.append(os.path.join(project, filename))                               # 파일 경로(path)를 화일 이름 앞에 부착하여 리스트에 추가
    return(r)

# 학습 데이터 생성 -------------------------------------------------------------
class CustomDataset(Dataset):
    def __init__(self, imageList, angleList):
        self.imageList = imgPaths(imageList)
        self.angleList = angleList

        for i in range(len(imageList)):
            image = cv2.imread(self.imageList[i])
            image = image / 255
            self.imageList[i] = image

    def __len__(self):
        return len(self.imageList)

    def __getitem__(self, index):
        images = torch.FloatTensor(self.imageList[index]).permute(2,0,1)
        angles = torch.FloatTensor([self.angleList[index]])
        return images, angles
#-------------------------------------------------------------------------------
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path=f'_{project}_model_check.pt'):
        """
            patience (int): validation loss가 개선된 후 기다리는 기간               - Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력  - Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화     - Default: 0
            path (str): checkpoint저장 경로
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'Early Stopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
# Out:
# cuda:0 is available

# %% [markdown]
# <STEP 5> 모델 학습

# %%
# 모델 학습 --------------------------------------------------------------------
def learnProc():
  model = NvidiaModel().to(device)

  train_dataset = CustomDataset(x_train_Image, y_train_Angle)
  train_loader = DataLoader(train_dataset, batch_size=len(x_train_Image))
  valid_dataset = CustomDataset(x_valid_Image, y_valid_Angle)
  valid_loader = DataLoader(valid_dataset, batch_size=len(x_valid_Image))
  optimizer = optim.Adam(model.parameters(), lr=learnRate)
  criterion = nn.MSELoss().to(device)
  early_stopping = EarlyStopping(patience=30, verbose=True)

  train_losses = []
  valid_losses = []
  avg_train_losses = []
  avg_valid_losses = []
  for epoch in range(1, EPOCHS + 1):
      # 학습
      model.train()

      for batch_idx, (data, target) in enumerate(train_loader):
          data, target = data.to(device), target.to(device)
          optimizer.zero_grad()

          output = model(data)

          loss = criterion(output.to(torch.float32), target.to(torch.float32))
          loss.backward()
          optimizer.step()

          train_losses.append(loss.item())

      # 검증
      model.eval()

      #with torch.no_grad():
      with torch.inference_mode():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)

            loss = criterion(output.to(torch.float32), target.to(torch.float32))

            valid_losses.append(loss.item())

      train_loss = np.average(train_losses)
      valid_loss = np.average(valid_losses)
      avg_train_losses.append(train_loss)
      avg_valid_losses.append(valid_loss)

      epoch_len = len(str(EPOCHS))

      print_msg = (f'[{epoch:>{epoch_len}}/{EPOCHS:>{epoch_len}}] ' +
                      f'train_loss: {train_loss:.6f} ' +
                      f'valid_loss: {valid_loss:.6f}')

      print(print_msg)

      train_losses = []
      valid_losses = []

      early_stopping(valid_loss, model)

      if early_stopping.early_stop:
          print("Early stopping")
          break

  return {'loss':avg_train_losses, 'val_loss':avg_valid_losses}

# 학습 시작---------------------------------------------------------------------
startTime = time.time()                                                         # 학습 시작 시간 저장
history = learnProc()                                                           # 학습 시작
elapsedTime = int(time.time() - startTime)                                      # 학습 경과 시간 저장
lossMin = min(history['loss'])                                                  # 딕셔너리 history의 'loss'키 데이터는 리스트, 최소값
val_lossMin = min(history['val_loss'])                                          # 딕셔너리 history의 'val_loss'키 데이터는 리스트, 최소값
#-------------------------------------------------------------------------------
plt.plot(history['loss'],color='blue')
plt.plot(history['val_loss'],color='red')
plt.legend([f'training loss Min: {lossMin:0.2f}', f'validation loss Min: {val_lossMin:0.2f}'])
plt.savefig(f'_{project}_result.png')                                           # plot 이미지 저장
# Out:
# [  1/300] train_loss: 559.582886 valid_loss: 534.768494
# Validation loss decreased (inf --> 534.768494).  Saving model ...
# [  2/300] train_loss: 558.537842 valid_loss: 532.401245
# Validation loss decreased (534.768494 --> 532.401245).  Saving model ...
# [  3/300] train_loss: 555.006470 valid_loss: 530.931335
# Validation loss decreased (532.401245 --> 530.931335).  Saving model ...
# [  4/300] train_loss: 551.477356 valid_loss: 533.688782
# Early Stopping counter: 1 out of 30
# [  5/300] train_loss: 551.841309 valid_loss: 534.681091
# Early Stopping counter: 2 out of 30
# [  6/300] train_loss: 552.102356 valid_loss: 532.705994
# Early Stopping counter: 3 out of 30
# [  7/300] train_loss: 551.195435 valid_loss: 531.336548
# Early Stopping counter: 4 out of 30
# [  8/300] train_loss: 550.817993 valid_loss: 530.831116
# Validation loss decreased (530.931335 --> 530.831116).  Saving model ...
# [  9/300] train_loss: 550.965881 valid_loss: 530.573914
# Validation loss decreased (530.831116 --> 530.573914).  Saving model ...
# [ 10/300] train_loss: 550.937744 valid_loss: 530.203918
# Validation loss decreased (530.573914 --> 530.203918).  Saving model ...
# [ 11/300] train_loss: 550.203857 valid_loss: 529.494080
# Validation loss decreased (530.203918 --> 529.494080).  Saving model ...
# [ 12/300] train_loss: 548.820435 valid_loss: 528.045776
# Validation loss decreased (529.494080 --> 528.045776).  Saving model ...
# [ 13/300] train_loss: 546.152222 valid_loss: 525.005188
# Validation loss decreased (528.045776 --> 525.005188).  Saving model ...
# [ 14/300] train_loss: 540.694946 valid_loss: 518.988647
# Validation loss decreased (525.005188 --> 518.988647).  Saving model ...
# [ 15/300] train_loss: 530.446594 valid_loss: 509.047516
# Validation loss decreased (518.988647 --> 509.047516).  Saving model ...
# [ 16/300] train_loss: 516.322693 valid_loss: 494.460541
# Validation loss decreased (509.047516 --> 494.460541).  Saving model ...
# [ 17/300] train_loss: 496.273102 valid_loss: 475.775665
# Validation loss decreased (494.460541 --> 475.775665).  Saving model ...
# [ 18/300] train_loss: 471.342377 valid_loss: 453.281250
# Validation loss decreased (475.775665 --> 453.281250).  Saving model ...
# [ 19/300] train_loss: 439.040405 valid_loss: 427.429199
# Validation loss decreased (453.281250 --> 427.429199).  Saving model ...
# [ 20/300] train_loss: 388.983673 valid_loss: 429.273895
# Early Stopping counter: 1 out of 30
# [ 21/300] train_loss: 347.203827 valid_loss: 484.148743
# Early Stopping counter: 2 out of 30
# [ 22/300] train_loss: 349.573975 valid_loss: 442.403198
# Early Stopping counter: 3 out of 30
# [ 23/300] train_loss: 307.477905 valid_loss: 411.940765
# Validation loss decreased (427.429199 --> 411.940765).  Saving model ...
# [ 24/300] train_loss: 288.148773 valid_loss: 394.391296
# Validation loss decreased (411.940765 --> 394.391296).  Saving model ...
# [ 25/300] train_loss: 281.179871 valid_loss: 362.975830
# Validation loss decreased (394.391296 --> 362.975830).  Saving model ...
# [ 26/300] train_loss: 268.154327 valid_loss: 358.041199
# Validation loss decreased (362.975830 --> 358.041199).  Saving model ...
# [ 27/300] train_loss: 242.459305 valid_loss: 328.856354
# Validation loss decreased (358.041199 --> 328.856354).  Saving model ...
# [ 28/300] train_loss: 235.308029 valid_loss: 312.798492
# Validation loss decreased (328.856354 --> 312.798492).  Saving model ...
# [ 29/300] train_loss: 227.898300 valid_loss: 277.968201
# Validation loss decreased (312.798492 --> 277.968201).  Saving model ...
# [ 30/300] train_loss: 206.436005 valid_loss: 248.911209
# Validation loss decreased (277.968201 --> 248.911209).  Saving model ...
# [ 31/300] train_loss: 191.112152 valid_loss: 230.372330
# Validation loss decreased (248.911209 --> 230.372330).  Saving model ...
# [ 32/300] train_loss: 181.669205 valid_loss: 218.494202
# Validation loss decreased (230.372330 --> 218.494202).  Saving model ...
# [ 33/300] train_loss: 173.958710 valid_loss: 206.883408
# Validation loss decreased (218.494202 --> 206.883408).  Saving model ...
# [ 34/300] train_loss: 166.711624 valid_loss: 197.123566
# Validation loss decreased (206.883408 --> 197.123566).  Saving model ...
# [ 35/300] train_loss: 158.617126 valid_loss: 189.303513
# Validation loss decreased (197.123566 --> 189.303513).  Saving model ...
# [ 36/300] train_loss: 152.049774 valid_loss: 181.339920
# Validation loss decreased (189.303513 --> 181.339920).  Saving model ...
# [ 37/300] train_loss: 146.953384 valid_loss: 174.410645
# Validation loss decreased (181.339920 --> 174.410645).  Saving model ...
# [ 38/300] train_loss: 138.021347 valid_loss: 170.052765
# Validation loss decreased (174.410645 --> 170.052765).  Saving model ...
# [ 39/300] train_loss: 135.252502 valid_loss: 164.457047
# Validation loss decreased (170.052765 --> 164.457047).  Saving model ...
# [ 40/300] train_loss: 127.267776 valid_loss: 152.249405
# Validation loss decreased (164.457047 --> 152.249405).  Saving model ...
# [ 41/300] train_loss: 120.598778 valid_loss: 141.076584
# Validation loss decreased (152.249405 --> 141.076584).  Saving model ...
# [ 42/300] train_loss: 119.178299 valid_loss: 133.018936
# Validation loss decreased (141.076584 --> 133.018936).  Saving model ...
# [ 43/300] train_loss: 115.711464 valid_loss: 128.167435
# Validation loss decreased (133.018936 --> 128.167435).  Saving model ...
# [ 44/300] train_loss: 114.642761 valid_loss: 121.620865
# Validation loss decreased (128.167435 --> 121.620865).  Saving model ...
# [ 45/300] train_loss: 107.611374 valid_loss: 118.842751
# Validation loss decreased (121.620865 --> 118.842751).  Saving model ...
# [ 46/300] train_loss: 105.041092 valid_loss: 117.387611
# Validation loss decreased (118.842751 --> 117.387611).  Saving model ...
# [ 47/300] train_loss: 101.902946 valid_loss: 115.200851
# Validation loss decreased (117.387611 --> 115.200851).  Saving model ...
# [ 48/300] train_loss: 102.890862 valid_loss: 111.992065
# Validation loss decreased (115.200851 --> 111.992065).  Saving model ...
# [ 49/300] train_loss: 99.410362 valid_loss: 108.743782
# Validation loss decreased (111.992065 --> 108.743782).  Saving model ...
# [ 50/300] train_loss: 97.457901 valid_loss: 106.130478
# Validation loss decreased (108.743782 --> 106.130478).  Saving model ...
# [ 51/300] train_loss: 93.776573 valid_loss: 105.068520
# Validation loss decreased (106.130478 --> 105.068520).  Saving model ...
# [ 52/300] train_loss: 92.962875 valid_loss: 105.739059
# Early Stopping counter: 1 out of 30
# [ 53/300] train_loss: 93.885239 valid_loss: 105.425995
# Early Stopping counter: 2 out of 30
# [ 54/300] train_loss: 87.144051 valid_loss: 105.954735
# Early Stopping counter: 3 out of 30
# [ 55/300] train_loss: 89.621696 valid_loss: 107.679497
# Early Stopping counter: 4 out of 30
# [ 56/300] train_loss: 83.172737 valid_loss: 108.490852
# Early Stopping counter: 5 out of 30
# [ 57/300] train_loss: 86.957527 valid_loss: 112.023895
# Early Stopping counter: 6 out of 30
# [ 58/300] train_loss: 88.739639 valid_loss: 109.627731
# Early Stopping counter: 7 out of 30
# [ 59/300] train_loss: 85.135170 valid_loss: 107.504143
# Early Stopping counter: 8 out of 30
# [ 60/300] train_loss: 79.999100 valid_loss: 108.641815
# Early Stopping counter: 9 out of 30
# [ 61/300] train_loss: 79.827057 valid_loss: 106.963905
# Early Stopping counter: 10 out of 30
# [ 62/300] train_loss: 74.134941 valid_loss: 108.083427
# Early Stopping counter: 11 out of 30
# [ 63/300] train_loss: 76.213417 valid_loss: 106.964684
# Early Stopping counter: 12 out of 30
# [ 64/300] train_loss: 72.408028 valid_loss: 108.140694
# Early Stopping counter: 13 out of 30
# [ 65/300] train_loss: 71.000771 valid_loss: 107.746269
# Early Stopping counter: 14 out of 30
# [ 66/300] train_loss: 71.485962 valid_loss: 107.942314
# Early Stopping counter: 15 out of 30
# [ 67/300] train_loss: 70.764107 valid_loss: 105.763130
# Early Stopping counter: 16 out of 30
# [ 68/300] train_loss: 68.354050 valid_loss: 104.479935
# Validation loss decreased (105.068520 --> 104.479935).  Saving model ...
# [ 69/300] train_loss: 67.712112 valid_loss: 105.019485
# Early Stopping counter: 1 out of 30
# [ 70/300] train_loss: 69.420319 valid_loss: 105.345459
# Early Stopping counter: 2 out of 30
# [ 71/300] train_loss: 66.543655 valid_loss: 105.271324
# Early Stopping counter: 3 out of 30
# [ 72/300] train_loss: 63.742947 valid_loss: 106.630211
# Early Stopping counter: 4 out of 30
# [ 73/300] train_loss: 62.538994 valid_loss: 106.845200
# Early Stopping counter: 5 out of 30
# [ 74/300] train_loss: 62.436729 valid_loss: 105.461891
# Early Stopping counter: 6 out of 30
# [ 75/300] train_loss: 59.767925 valid_loss: 103.722008
# Validation loss decreased (104.479935 --> 103.722008).  Saving model ...
# [ 76/300] train_loss: 58.004265 valid_loss: 103.015961
# Validation loss decreased (103.722008 --> 103.015961).  Saving model ...
# [ 77/300] train_loss: 59.838806 valid_loss: 103.053078
# Early Stopping counter: 1 out of 30
# [ 78/300] train_loss: 58.550655 valid_loss: 103.484779
# Early Stopping counter: 2 out of 30
# [ 79/300] train_loss: 55.217251 valid_loss: 104.170578
# Early Stopping counter: 3 out of 30
# [ 80/300] train_loss: 53.369419 valid_loss: 104.800842
# Early Stopping counter: 4 out of 30
# [ 81/300] train_loss: 53.029594 valid_loss: 105.127510
# Early Stopping counter: 5 out of 30
# [ 82/300] train_loss: 51.816357 valid_loss: 103.241081
# Early Stopping counter: 6 out of 30
# [ 83/300] train_loss: 51.235573 valid_loss: 103.687729
# Early Stopping counter: 7 out of 30
# [ 84/300] train_loss: 51.225792 valid_loss: 102.468292
# Validation loss decreased (103.015961 --> 102.468292).  Saving model ...
# [ 85/300] train_loss: 46.675747 valid_loss: 102.317688
# Validation loss decreased (102.468292 --> 102.317688).  Saving model ...
# [ 86/300] train_loss: 47.024006 valid_loss: 102.049881
# Validation loss decreased (102.317688 --> 102.049881).  Saving model ...
# [ 87/300] train_loss: 45.817104 valid_loss: 103.535782
# Early Stopping counter: 1 out of 30
# [ 88/300] train_loss: 44.674225 valid_loss: 103.335754
# Early Stopping counter: 2 out of 30
# [ 89/300] train_loss: 44.236168 valid_loss: 104.910980
# Early Stopping counter: 3 out of 30
# [ 90/300] train_loss: 47.277939 valid_loss: 105.416351
# Early Stopping counter: 4 out of 30
# [ 91/300] train_loss: 41.953434 valid_loss: 105.855225
# Early Stopping counter: 5 out of 30
# [ 92/300] train_loss: 40.774391 valid_loss: 108.307014
# Early Stopping counter: 6 out of 30
# [ 93/300] train_loss: 39.139236 valid_loss: 108.167007
# Early Stopping counter: 7 out of 30
# [ 94/300] train_loss: 39.921749 valid_loss: 108.176155
# Early Stopping counter: 8 out of 30
# [ 95/300] train_loss: 37.961548 valid_loss: 108.415756
# Early Stopping counter: 9 out of 30
# [ 96/300] train_loss: 37.023876 valid_loss: 108.970543
# Early Stopping counter: 10 out of 30
# [ 97/300] train_loss: 34.846169 valid_loss: 109.948029
# Early Stopping counter: 11 out of 30
# [ 98/300] train_loss: 33.407684 valid_loss: 111.389404
# Early Stopping counter: 12 out of 30
# [ 99/300] train_loss: 36.475075 valid_loss: 114.104668
# Early Stopping counter: 13 out of 30
# [100/300] train_loss: 36.323227 valid_loss: 114.011627
# Early Stopping counter: 14 out of 30
# [101/300] train_loss: 35.194946 valid_loss: 115.705116
# Early Stopping counter: 15 out of 30
# [102/300] train_loss: 34.835644 valid_loss: 120.560005
# Early Stopping counter: 16 out of 30
# [103/300] train_loss: 36.750397 valid_loss: 117.486702
# Early Stopping counter: 17 out of 30
# [104/300] train_loss: 36.490391 valid_loss: 115.649010
# Early Stopping counter: 18 out of 30
# [105/300] train_loss: 29.875029 valid_loss: 121.791565
# Early Stopping counter: 19 out of 30
# [106/300] train_loss: 32.263550 valid_loss: 116.480728
# Early Stopping counter: 20 out of 30
# [107/300] train_loss: 32.983021 valid_loss: 115.162209
# Early Stopping counter: 21 out of 30
# [108/300] train_loss: 29.948292 valid_loss: 118.655998
# Early Stopping counter: 22 out of 30
# [109/300] train_loss: 32.519676 valid_loss: 115.604836
# Early Stopping counter: 23 out of 30
# [110/300] train_loss: 25.629459 valid_loss: 116.139015
# Early Stopping counter: 24 out of 30
# [111/300] train_loss: 28.558199 valid_loss: 115.302155
# Early Stopping counter: 25 out of 30
# [112/300] train_loss: 28.241179 valid_loss: 116.055550
# Early Stopping counter: 26 out of 30
# [113/300] train_loss: 25.925394 valid_loss: 112.305992
# Early Stopping counter: 27 out of 30
# [114/300] train_loss: 25.725044 valid_loss: 111.744835
# Early Stopping counter: 28 out of 30
# [115/300] train_loss: 23.989334 valid_loss: 111.309990
# Early Stopping counter: 29 out of 30
# [116/300] train_loss: 24.795633 valid_loss: 117.678513
# Early Stopping counter: 30 out of 30
# Early stopping

# %% [markdown]
# <STEP 6> 학습 결과 표시, 테스트 파일 각도 예측

# %%
def resultShow():                                                               # 학습 완료후 통계자료를 보여줍니다.
  model = NvidiaModel().to(device)                                              # NvidiaModel 의 Summary를 표시합니다.
  summary(model,(3, 66, 200))

  test_dataset = CustomDataset(x_exam_Image, y_exam_Angle)
  test_loader = DataLoader(test_dataset, batch_size=len(x_exam_Image))

  model = NvidiaModel().to(device)
  model.load_state_dict(torch.load(f'_{project}_model_check.pt'))               # 모델 파일
  model.eval()

  y_pred = []
  y_target = []

  with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            print('pred', output.to(device).cpu().numpy())                                                              # GPU Edition
            print('target', target.to(device).cpu().numpy())                                                            #
            for output_data, target_data in zip(output.to(device).cpu().numpy(), target.to(device).cpu().numpy()):      #
              y_pred.append(output_data)
              y_target.append(target_data)

  mse = mean_squared_error(y_target, y_pred)
  r2s = r2_score(y_target, y_pred)
  #-----------------------------------------------------------------------------
  print('\n표준 편차:', f'{mse:.2f}')
  print('회귀 결정 계수:', f'{r2s:.2%}')
  #-----------------------------------------------------------------------------
  fig, axes = plt.subplots(1, len(x_exam_Image), figsize=(30, 2+3))
  xTImg = imgPaths(x_exam_Image)                                                # 파일 이름 앞에 경로(path) 추가
  for x, c in enumerate(xTImg):
    yuv_image = cv2.imread(c, cv2.IMREAD_UNCHANGED)                             # 테스트 이미지 읽기
    bgr_image = cv2.cvtColor(yuv_image, cv2.COLOR_YUV2BGR)                      # YUV 이미지를 BGR 형식으로 변환
    rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)                      # MatPlot Lib 에서 표시되는 RGB 형식으로 변환
    axes[x].imshow(rgb_image)
    t = x_exam_Image[x] +' / E:'+str(int(y_pred[x]))
    axes[x].set_title(t, fontsize=15)
    axes[x].xaxis.set_ticks([])
    axes[x].yaxis.set_ticks([])

if len(x_exam_Image): resultShow()
print("학습 소요 시간:", int(elapsedTime/60), '분', elapsedTime%60, '초' )      # 학습 소요시간 프린트
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 24, 31, 98]           1,824
#                ELU-2           [-1, 24, 31, 98]               0
#             Conv2d-3           [-1, 36, 14, 47]          21,636
#                ELU-4           [-1, 36, 14, 47]               0
#             Conv2d-5            [-1, 48, 5, 22]          43,248
#                ELU-6            [-1, 48, 5, 22]               0
#             Conv2d-7            [-1, 64, 3, 20]          27,712
#                ELU-8            [-1, 64, 3, 20]               0
#            Dropout-9            [-1, 64, 3, 20]               0
#            Conv2d-10            [-1, 64, 1, 18]          36,928
#               ELU-11            [-1, 64, 1, 18]               0
#           Dropout-12                 [-1, 1152]               0
#            Linear-13                  [-1, 100]         115,300
#               ELU-14                  [-1, 100]               0
#            Linear-15                   [-1, 50]           5,050
#               ELU-16                   [-1, 50]               0
#            Linear-17                   [-1, 10]             510
#               ELU-18                   [-1, 10]               0
#            Linear-19                    [-1, 1]              11
# ================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.15
# Forward/backward pass size (MB): 1.67
# Params size (MB): 0.96
# Estimated Total Size (MB): 2.78
# ----------------------------------------------------------------
# pred [[-45.07442  ]
#  [-34.37367  ]
#  [ -4.4225345]
#  [ -3.0490365]
#  [ 25.030298 ]
#  [ 23.301933 ]]
# target [[-49.]
#  [-40.]
#  [-11.]
#  [  0.]
#  [ 14.]
#  [ 25.]]
#
# 표준 편차: 37.36
# 회귀 결정 계수: 94.81%
# 학습 소요 시간: 0 분 22 초
# /tmp/ipython-input-1763350081.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   t = x_exam_Image[x] +' / E:'+str(int(y_pred[x]))

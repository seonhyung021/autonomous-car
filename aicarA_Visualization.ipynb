# %% [markdown]
# AICAR 자율주행 자동차 --------------------------------------------------  <aicarA.ipynb>  2024-04-08
# 1. Raspberry Pi 에서 도로 이미지 압축한 ZIP 파일을 올려 놓습니다.
# 2. Colab 메뉴 -> 런타임 -> 런타임 유형변경 -> T4 GPU를 선택하고 저장합니다.
# 3. Colab 메뉴 -> 런타임 -> 모두 실행을 선택합니다.
# 4. *.pt 파일을 다운로드 합니다.

# %% [markdown]
# <STEP 1>이미지 파일 압축 풀기 - 실행 하기 전 압축파일(*.zip)을 올려 놓아야 합니다.

# %%
EPOCHS = None; learnRate = None                                                 # epochN = 300, learnRate = 0.0005/0.0010/0.0015/0.0020/0.0025
import glob
import zipfile
fileList = glob.glob('*.zip')
zip_ref = zipfile.ZipFile(fileList[0], 'r');
zip_ref.extractall()
zip_ref.close()
w = fileList[0].split('.'); project = w[-2]
print('프로젝트:',project)
# Out:
# 프로젝트: track1125

# %% [markdown]
# <STEP 2> 라이브러리 가져오기(Import)

# %%
import os
import sys
import random
import fnmatch
import pickle
import time
import numpy as np
import cv2                                                                      # Open Cv 영상처리 라이브러리
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary as summary
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline
from PIL import Image

print(f'Python Version:     {sys.version}')                                     # Python Version
print(f'OpenCV version:     {cv2.__version__}')                                  # Open CV version
print(f'Pytorch version:    {torch.__version__}')                               # Pytorch version
# Out:
# Python Version:     3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# OpenCV version:     4.13.0
# Pytorch version:    2.10.0+cu128

# %% [markdown]
# <STEP 3> 이미지 데이터 조향각 추출

# %%
with open(f'{project}/_{project}.pickle', 'rb') as f:                           # pickle 파일
    x_exam_Image = pickle.load(f)                                               # 시험(Test) 이미지 파일 이름 리스트
    x_valid_Image = pickle.load(f)                                              # 평가(Valid) 이미지 파일 이름 리스트
    x_train_Image = pickle.load(f)                                              # 훈련(Train) 이미지 파일 이름 리스트
    p = pickle.load(f)                                                          # 파라메터 리스트
if EPOCHS == None: EPOCHS = p[0]                                                # 학습회수
if learnRate == None: learnRate = p[1]                                          # 학습 비율 0.0005/0.0010/0.0015/0.0020/0.0025
#-------------------------------------------------------------------------------
y_exam_Angle=[]
y_valid_Angle=[]
y_train_Angle = []
for f in x_exam_Image:                                                          # 시험용 이미지 파일 이름에서 각도값
    y_exam_Angle.append(int(f[-7:-4]))
for f in x_valid_Image:                                                         # 평가용 이미지 파일 이름에서 각도값
    y_valid_Angle.append(int(f[-7:-4]))
for f in x_train_Image:                                                         # 훈련용 이미지 파일 이름에서 각도값
    y_train_Angle.append(int(f[-7:-4]))

print('학습 회수:',EPOCHS,)
print('학습 비율', learnRate)
print('시험 이미지 개수:',len(x_exam_Image))
print('평가 이미지 개수:',len(x_valid_Image))
print('훈련 이미지 개수:',len(x_train_Image))
# Out:
# 학습 회수: 300
# 학습 비율 0.001
# 시험 이미지 개수: 7
# 평가 이미지 개수: 302
# 훈련 이미지 개수: 1726

# %% [markdown]
# <STEP 4> Nvidia CNN 모델 구성

# %%
# Pytorch device 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f'{device} is available')

# Nvidia CNN 모델 구성 ---------------------------------------------------------
class NvidiaModel(nn.Module):
    def __init__(self):
      super(NvidiaModel, self).__init__()

      # elu=Expenential Linear Unit, similar to leaky Relu
      # skipping 1st hiddel layer (nomralization layer), as we have normalized the data

      # Convolution Layers
      self.layer1 = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=24, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=24, out_channels=36, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=36, out_channels=48, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=48, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True),
        nn.Dropout(0.2),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True)
      )

      # Fully Connected Layers
      self.layer2 = nn.Sequential(
        # nn.Flatten(),
        nn.Dropout(0.2),
        nn.Linear(in_features=18 * 64, out_features=100),
        nn.ELU(inplace=True),
        nn.Linear(in_features=100, out_features=50),
        nn.ELU(inplace=True),
        nn.Linear(in_features=50, out_features=10),
        nn.ELU(inplace=True)
      )

      # Output Layer
      self.layer3 = nn.Sequential(
        nn.Linear(in_features=10, out_features=1)
      )

    def forward(self, x):
      x = self.layer1(x)
      x = x.view(x.shape[0], -1)
      x = self.layer2(x)
      x = self.layer3(x)

      return x
#-------------------------------------------------------------------------------
def imgPaths(fGroup):
    r = []
    for filename in fGroup:
        r.append(os.path.join(project, filename))                               # 파일 경로(path)를 화일 이름 앞에 부착하여 리스트에 추가
    return(r)

# 학습 데이터 생성 -------------------------------------------------------------
class CustomDataset(Dataset):
    def __init__(self, imageList, angleList):
        self.imageList = imgPaths(imageList)
        self.angleList = angleList

        for i in range(len(imageList)):
            image = cv2.imread(self.imageList[i])
            image = image / 255
            self.imageList[i] = image

    def __len__(self):
        return len(self.imageList)

    def __getitem__(self, index):
        images = torch.FloatTensor(self.imageList[index]).permute(2,0,1)
        angles = torch.FloatTensor([self.angleList[index]])
        return images, angles
#-------------------------------------------------------------------------------
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path=f'_{project}_model_check.pt'):
        """
            patience (int): validation loss가 개선된 후 기다리는 기간               - Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력  - Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화     - Default: 0
            path (str): checkpoint저장 경로
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'Early Stopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
# Out:
# cuda:0 is available

# %% [markdown]
# <STEP 5> 모델 학습

# %%
# 모델 학습 --------------------------------------------------------------------
def learnProc():
  model = NvidiaModel().to(device)

  train_dataset = CustomDataset(x_train_Image, y_train_Angle)
  train_loader = DataLoader(train_dataset, batch_size=len(x_train_Image))
  valid_dataset = CustomDataset(x_valid_Image, y_valid_Angle)
  valid_loader = DataLoader(valid_dataset, batch_size=len(x_valid_Image))
  optimizer = optim.Adam(model.parameters(), lr=learnRate)
  criterion = nn.MSELoss().to(device)
  early_stopping = EarlyStopping(patience=30, verbose=True)

  train_losses = []
  valid_losses = []
  avg_train_losses = []
  avg_valid_losses = []
  for epoch in range(1, EPOCHS + 1):
      # 학습
      model.train()

      for batch_idx, (data, target) in enumerate(train_loader):
          data, target = data.to(device), target.to(device)
          optimizer.zero_grad()

          output = model(data)

          loss = criterion(output.to(torch.float32), target.to(torch.float32))
          loss.backward()
          optimizer.step()

          train_losses.append(loss.item())

      # 검증
      model.eval()

      #with torch.no_grad():
      with torch.inference_mode():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)

            loss = criterion(output.to(torch.float32), target.to(torch.float32))

            valid_losses.append(loss.item())

      train_loss = np.average(train_losses)
      valid_loss = np.average(valid_losses)
      avg_train_losses.append(train_loss)
      avg_valid_losses.append(valid_loss)

      epoch_len = len(str(EPOCHS))

      print_msg = (f'[{epoch:>{epoch_len}}/{EPOCHS:>{epoch_len}}] ' +
                      f'train_loss: {train_loss:.6f} ' +
                      f'valid_loss: {valid_loss:.6f}')

      print(print_msg)

      train_losses = []
      valid_losses = []

      early_stopping(valid_loss, model)

      if early_stopping.early_stop:
          print("Early stopping")
          break

  return {'loss':avg_train_losses, 'val_loss':avg_valid_losses}

# 학습 시작---------------------------------------------------------------------
startTime = time.time()                                                         # 학습 시작 시간 저장
history = learnProc()                                                           # 학습 시작
elapsedTime = int(time.time() - startTime)                                      # 학습 경과 시간 저장
lossMin = min(history['loss'])                                                  # 딕셔너리 history의 'loss'키 데이터는 리스트, 최소값
val_lossMin = min(history['val_loss'])                                          # 딕셔너리 history의 'val_loss'키 데이터는 리스트, 최소값
#-------------------------------------------------------------------------------
plt.plot(history['loss'],color='blue')
plt.plot(history['val_loss'],color='red')
plt.legend([f'training loss Min: {lossMin:0.2f}', f'validation loss Min: {val_lossMin:0.2f}'])
plt.savefig(f'_{project}_result.png')                                           # plot 이미지 저장
# Out:
# [  1/300] train_loss: 819.370911 valid_loss: 817.955078
# Validation loss decreased (inf --> 817.955078).  Saving model ...
# [  2/300] train_loss: 819.192749 valid_loss: 817.747131
# Validation loss decreased (817.955078 --> 817.747131).  Saving model ...
# [  3/300] train_loss: 818.823975 valid_loss: 817.599548
# Validation loss decreased (817.747131 --> 817.599548).  Saving model ...
# [  4/300] train_loss: 818.453308 valid_loss: 816.757141
# Validation loss decreased (817.599548 --> 816.757141).  Saving model ...
# [  5/300] train_loss: 817.545776 valid_loss: 810.989990
# Validation loss decreased (816.757141 --> 810.989990).  Saving model ...
# [  6/300] train_loss: 811.956970 valid_loss: 805.746582
# Validation loss decreased (810.989990 --> 805.746582).  Saving model ...
# [  7/300] train_loss: 806.368469 valid_loss: 798.896606
# Validation loss decreased (805.746582 --> 798.896606).  Saving model ...
# [  8/300] train_loss: 798.934814 valid_loss: 791.176819
# Validation loss decreased (798.896606 --> 791.176819).  Saving model ...
# [  9/300] train_loss: 791.263367 valid_loss: 779.258362
# Validation loss decreased (791.176819 --> 779.258362).  Saving model ...
# [ 10/300] train_loss: 778.763306 valid_loss: 764.586426
# Validation loss decreased (779.258362 --> 764.586426).  Saving model ...
# [ 11/300] train_loss: 763.193359 valid_loss: 741.035034
# Validation loss decreased (764.586426 --> 741.035034).  Saving model ...
# [ 12/300] train_loss: 739.202026 valid_loss: 712.403381
# Validation loss decreased (741.035034 --> 712.403381).  Saving model ...
# [ 13/300] train_loss: 710.533936 valid_loss: 665.260742
# Validation loss decreased (712.403381 --> 665.260742).  Saving model ...
# [ 14/300] train_loss: 659.983887 valid_loss: 617.803284
# Validation loss decreased (665.260742 --> 617.803284).  Saving model ...
# [ 15/300] train_loss: 614.638245 valid_loss: 554.716003
# Validation loss decreased (617.803284 --> 554.716003).  Saving model ...
# [ 16/300] train_loss: 541.463440 valid_loss: 517.437500
# Validation loss decreased (554.716003 --> 517.437500).  Saving model ...
# [ 17/300] train_loss: 505.691406 valid_loss: 494.304749
# Validation loss decreased (517.437500 --> 494.304749).  Saving model ...
# [ 18/300] train_loss: 472.474213 valid_loss: 438.441833
# Validation loss decreased (494.304749 --> 438.441833).  Saving model ...
# [ 19/300] train_loss: 425.217896 valid_loss: 397.508331
# Validation loss decreased (438.441833 --> 397.508331).  Saving model ...
# [ 20/300] train_loss: 385.639679 valid_loss: 352.780487
# Validation loss decreased (397.508331 --> 352.780487).  Saving model ...
# [ 21/300] train_loss: 357.058990 valid_loss: 333.633118
# Validation loss decreased (352.780487 --> 333.633118).  Saving model ...
# [ 22/300] train_loss: 337.089661 valid_loss: 328.821747
# Validation loss decreased (333.633118 --> 328.821747).  Saving model ...
# [ 23/300] train_loss: 325.527283 valid_loss: 314.976471
# Validation loss decreased (328.821747 --> 314.976471).  Saving model ...
# [ 24/300] train_loss: 310.021362 valid_loss: 301.789215
# Validation loss decreased (314.976471 --> 301.789215).  Saving model ...
# [ 25/300] train_loss: 290.247101 valid_loss: 291.432983
# Validation loss decreased (301.789215 --> 291.432983).  Saving model ...
# [ 26/300] train_loss: 274.730194 valid_loss: 277.428436
# Validation loss decreased (291.432983 --> 277.428436).  Saving model ...
# [ 27/300] train_loss: 265.980927 valid_loss: 264.040253
# Validation loss decreased (277.428436 --> 264.040253).  Saving model ...
# [ 28/300] train_loss: 250.588959 valid_loss: 251.004288
# Validation loss decreased (264.040253 --> 251.004288).  Saving model ...
# [ 29/300] train_loss: 235.973450 valid_loss: 241.736862
# Validation loss decreased (251.004288 --> 241.736862).  Saving model ...
# [ 30/300] train_loss: 223.583817 valid_loss: 234.655350
# Validation loss decreased (241.736862 --> 234.655350).  Saving model ...
# [ 31/300] train_loss: 215.838135 valid_loss: 229.210052
# Validation loss decreased (234.655350 --> 229.210052).  Saving model ...
# [ 32/300] train_loss: 208.764999 valid_loss: 223.355759
# Validation loss decreased (229.210052 --> 223.355759).  Saving model ...
# [ 33/300] train_loss: 202.558472 valid_loss: 216.418869
# Validation loss decreased (223.355759 --> 216.418869).  Saving model ...
# [ 34/300] train_loss: 193.327530 valid_loss: 207.201965
# Validation loss decreased (216.418869 --> 207.201965).  Saving model ...
# [ 35/300] train_loss: 182.781937 valid_loss: 197.964066
# Validation loss decreased (207.201965 --> 197.964066).  Saving model ...
# [ 36/300] train_loss: 174.586044 valid_loss: 190.994232
# Validation loss decreased (197.964066 --> 190.994232).  Saving model ...
# [ 37/300] train_loss: 166.112091 valid_loss: 185.204636
# Validation loss decreased (190.994232 --> 185.204636).  Saving model ...
# [ 38/300] train_loss: 162.225830 valid_loss: 179.950073
# Validation loss decreased (185.204636 --> 179.950073).  Saving model ...
# [ 39/300] train_loss: 155.946075 valid_loss: 176.329391
# Validation loss decreased (179.950073 --> 176.329391).  Saving model ...
# [ 40/300] train_loss: 153.335312 valid_loss: 171.986542
# Validation loss decreased (176.329391 --> 171.986542).  Saving model ...
# [ 41/300] train_loss: 148.801773 valid_loss: 166.522369
# Validation loss decreased (171.986542 --> 166.522369).  Saving model ...
# [ 42/300] train_loss: 143.329422 valid_loss: 160.145676
# Validation loss decreased (166.522369 --> 160.145676).  Saving model ...
# [ 43/300] train_loss: 137.805283 valid_loss: 153.846680
# Validation loss decreased (160.145676 --> 153.846680).  Saving model ...
# [ 44/300] train_loss: 135.982681 valid_loss: 148.022552
# Validation loss decreased (153.846680 --> 148.022552).  Saving model ...
# [ 45/300] train_loss: 129.828812 valid_loss: 142.999786
# Validation loss decreased (148.022552 --> 142.999786).  Saving model ...
# [ 46/300] train_loss: 124.543991 valid_loss: 138.385651
# Validation loss decreased (142.999786 --> 138.385651).  Saving model ...
# [ 47/300] train_loss: 119.585548 valid_loss: 134.345367
# Validation loss decreased (138.385651 --> 134.345367).  Saving model ...
# [ 48/300] train_loss: 114.551361 valid_loss: 131.723679
# Validation loss decreased (134.345367 --> 131.723679).  Saving model ...
# [ 49/300] train_loss: 113.312859 valid_loss: 128.395081
# Validation loss decreased (131.723679 --> 128.395081).  Saving model ...
# [ 50/300] train_loss: 109.468460 valid_loss: 125.431236
# Validation loss decreased (128.395081 --> 125.431236).  Saving model ...
# [ 51/300] train_loss: 104.048157 valid_loss: 123.478668
# Validation loss decreased (125.431236 --> 123.478668).  Saving model ...
# [ 52/300] train_loss: 103.124855 valid_loss: 121.727600
# Validation loss decreased (123.478668 --> 121.727600).  Saving model ...
# [ 53/300] train_loss: 99.439400 valid_loss: 118.212074
# Validation loss decreased (121.727600 --> 118.212074).  Saving model ...
# [ 54/300] train_loss: 97.610207 valid_loss: 115.184891
# Validation loss decreased (118.212074 --> 115.184891).  Saving model ...
# [ 55/300] train_loss: 95.812012 valid_loss: 112.538300
# Validation loss decreased (115.184891 --> 112.538300).  Saving model ...
# [ 56/300] train_loss: 93.099777 valid_loss: 110.823807
# Validation loss decreased (112.538300 --> 110.823807).  Saving model ...
# [ 57/300] train_loss: 89.189255 valid_loss: 109.328110
# Validation loss decreased (110.823807 --> 109.328110).  Saving model ...
# [ 58/300] train_loss: 87.331322 valid_loss: 106.363968
# Validation loss decreased (109.328110 --> 106.363968).  Saving model ...
# [ 59/300] train_loss: 85.748184 valid_loss: 104.071083
# Validation loss decreased (106.363968 --> 104.071083).  Saving model ...
# [ 60/300] train_loss: 82.200142 valid_loss: 102.083771
# Validation loss decreased (104.071083 --> 102.083771).  Saving model ...
# [ 61/300] train_loss: 81.712517 valid_loss: 97.707382
# Validation loss decreased (102.083771 --> 97.707382).  Saving model ...
# [ 62/300] train_loss: 78.439384 valid_loss: 93.936447
# Validation loss decreased (97.707382 --> 93.936447).  Saving model ...
# [ 63/300] train_loss: 76.137199 valid_loss: 91.182030
# Validation loss decreased (93.936447 --> 91.182030).  Saving model ...
# [ 64/300] train_loss: 75.386703 valid_loss: 88.395851
# Validation loss decreased (91.182030 --> 88.395851).  Saving model ...
# [ 65/300] train_loss: 72.359566 valid_loss: 85.734390
# Validation loss decreased (88.395851 --> 85.734390).  Saving model ...
# [ 66/300] train_loss: 69.669815 valid_loss: 83.782402
# Validation loss decreased (85.734390 --> 83.782402).  Saving model ...
# [ 67/300] train_loss: 67.833588 valid_loss: 80.328613
# Validation loss decreased (83.782402 --> 80.328613).  Saving model ...
# [ 68/300] train_loss: 65.900589 valid_loss: 78.498795
# Validation loss decreased (80.328613 --> 78.498795).  Saving model ...
# [ 69/300] train_loss: 64.072899 valid_loss: 76.886497
# Validation loss decreased (78.498795 --> 76.886497).  Saving model ...
# [ 70/300] train_loss: 62.583351 valid_loss: 73.642540
# Validation loss decreased (76.886497 --> 73.642540).  Saving model ...
# [ 71/300] train_loss: 58.552479 valid_loss: 71.721039
# Validation loss decreased (73.642540 --> 71.721039).  Saving model ...
# [ 72/300] train_loss: 56.721382 valid_loss: 70.733253
# Validation loss decreased (71.721039 --> 70.733253).  Saving model ...
# [ 73/300] train_loss: 59.065712 valid_loss: 68.463097
# Validation loss decreased (70.733253 --> 68.463097).  Saving model ...
# [ 74/300] train_loss: 57.560295 valid_loss: 64.953217
# Validation loss decreased (68.463097 --> 64.953217).  Saving model ...
# [ 75/300] train_loss: 52.846668 valid_loss: 62.240818
# Validation loss decreased (64.953217 --> 62.240818).  Saving model ...
# [ 76/300] train_loss: 54.402828 valid_loss: 61.139023
# Validation loss decreased (62.240818 --> 61.139023).  Saving model ...
# [ 77/300] train_loss: 51.441948 valid_loss: 58.992626
# Validation loss decreased (61.139023 --> 58.992626).  Saving model ...
# [ 78/300] train_loss: 51.368374 valid_loss: 57.665600
# Validation loss decreased (58.992626 --> 57.665600).  Saving model ...
# [ 79/300] train_loss: 49.401283 valid_loss: 55.873260
# Validation loss decreased (57.665600 --> 55.873260).  Saving model ...
# [ 80/300] train_loss: 47.863934 valid_loss: 54.270435
# Validation loss decreased (55.873260 --> 54.270435).  Saving model ...
# [ 81/300] train_loss: 49.317829 valid_loss: 52.930027
# Validation loss decreased (54.270435 --> 52.930027).  Saving model ...
# [ 82/300] train_loss: 46.988117 valid_loss: 51.701241
# Validation loss decreased (52.930027 --> 51.701241).  Saving model ...
# [ 83/300] train_loss: 46.122299 valid_loss: 50.760895
# Validation loss decreased (51.701241 --> 50.760895).  Saving model ...
# [ 84/300] train_loss: 45.262882 valid_loss: 49.043446
# Validation loss decreased (50.760895 --> 49.043446).  Saving model ...
# [ 85/300] train_loss: 44.614941 valid_loss: 48.751862
# Validation loss decreased (49.043446 --> 48.751862).  Saving model ...
# [ 86/300] train_loss: 44.284336 valid_loss: 49.019848
# Early Stopping counter: 1 out of 30
# [ 87/300] train_loss: 42.828403 valid_loss: 49.359737
# Early Stopping counter: 2 out of 30
# [ 88/300] train_loss: 42.864532 valid_loss: 49.163662
# Early Stopping counter: 3 out of 30
# [ 89/300] train_loss: 41.231136 valid_loss: 48.738831
# Validation loss decreased (48.751862 --> 48.738831).  Saving model ...
# [ 90/300] train_loss: 41.092102 valid_loss: 48.213154
# Validation loss decreased (48.738831 --> 48.213154).  Saving model ...
# [ 91/300] train_loss: 40.656929 valid_loss: 47.273891
# Validation loss decreased (48.213154 --> 47.273891).  Saving model ...
# [ 92/300] train_loss: 39.436932 valid_loss: 47.105553
# Validation loss decreased (47.273891 --> 47.105553).  Saving model ...
# [ 93/300] train_loss: 39.047119 valid_loss: 46.780830
# Validation loss decreased (47.105553 --> 46.780830).  Saving model ...
# [ 94/300] train_loss: 39.404709 valid_loss: 47.586288
# Early Stopping counter: 1 out of 30
# [ 95/300] train_loss: 38.548195 valid_loss: 47.215775
# Early Stopping counter: 2 out of 30
# [ 96/300] train_loss: 37.277782 valid_loss: 46.565800
# Validation loss decreased (46.780830 --> 46.565800).  Saving model ...
# [ 97/300] train_loss: 37.891987 valid_loss: 45.430470
# Validation loss decreased (46.565800 --> 45.430470).  Saving model ...
# [ 98/300] train_loss: 36.981491 valid_loss: 43.965218
# Validation loss decreased (45.430470 --> 43.965218).  Saving model ...
# [ 99/300] train_loss: 36.213543 valid_loss: 43.523529
# Validation loss decreased (43.965218 --> 43.523529).  Saving model ...
# [100/300] train_loss: 36.237076 valid_loss: 42.961525
# Validation loss decreased (43.523529 --> 42.961525).  Saving model ...
# [101/300] train_loss: 34.866234 valid_loss: 42.843960
# Validation loss decreased (42.961525 --> 42.843960).  Saving model ...
# [102/300] train_loss: 35.335461 valid_loss: 41.930122
# Validation loss decreased (42.843960 --> 41.930122).  Saving model ...
# [103/300] train_loss: 33.942787 valid_loss: 41.899914
# Validation loss decreased (41.930122 --> 41.899914).  Saving model ...
# [104/300] train_loss: 33.901489 valid_loss: 41.275909
# Validation loss decreased (41.899914 --> 41.275909).  Saving model ...
# [105/300] train_loss: 32.617790 valid_loss: 40.865673
# Validation loss decreased (41.275909 --> 40.865673).  Saving model ...
# [106/300] train_loss: 33.127064 valid_loss: 39.834126
# Validation loss decreased (40.865673 --> 39.834126).  Saving model ...
# [107/300] train_loss: 32.845818 valid_loss: 39.056324
# Validation loss decreased (39.834126 --> 39.056324).  Saving model ...
# [108/300] train_loss: 32.479874 valid_loss: 38.203861
# Validation loss decreased (39.056324 --> 38.203861).  Saving model ...
# [109/300] train_loss: 31.681030 valid_loss: 37.646233
# Validation loss decreased (38.203861 --> 37.646233).  Saving model ...
# [110/300] train_loss: 30.744219 valid_loss: 37.128902
# Validation loss decreased (37.646233 --> 37.128902).  Saving model ...
# [111/300] train_loss: 30.812115 valid_loss: 36.251087
# Validation loss decreased (37.128902 --> 36.251087).  Saving model ...
# [112/300] train_loss: 31.230162 valid_loss: 35.761421
# Validation loss decreased (36.251087 --> 35.761421).  Saving model ...
# [113/300] train_loss: 30.033100 valid_loss: 34.880890
# Validation loss decreased (35.761421 --> 34.880890).  Saving model ...
# [114/300] train_loss: 29.339497 valid_loss: 34.145817
# Validation loss decreased (34.880890 --> 34.145817).  Saving model ...
# [115/300] train_loss: 28.902813 valid_loss: 33.817966
# Validation loss decreased (34.145817 --> 33.817966).  Saving model ...
# [116/300] train_loss: 29.050987 valid_loss: 33.191433
# Validation loss decreased (33.817966 --> 33.191433).  Saving model ...
# [117/300] train_loss: 28.467165 valid_loss: 32.674431
# Validation loss decreased (33.191433 --> 32.674431).  Saving model ...
# [118/300] train_loss: 27.859936 valid_loss: 32.395798
# Validation loss decreased (32.674431 --> 32.395798).  Saving model ...
# [119/300] train_loss: 27.299717 valid_loss: 32.301468
# Validation loss decreased (32.395798 --> 32.301468).  Saving model ...
# [120/300] train_loss: 27.527388 valid_loss: 32.175243
# Validation loss decreased (32.301468 --> 32.175243).  Saving model ...
# [121/300] train_loss: 28.706570 valid_loss: 31.272572
# Validation loss decreased (32.175243 --> 31.272572).  Saving model ...
# [122/300] train_loss: 25.865606 valid_loss: 30.540081
# Validation loss decreased (31.272572 --> 30.540081).  Saving model ...
# [123/300] train_loss: 26.046150 valid_loss: 30.003052
# Validation loss decreased (30.540081 --> 30.003052).  Saving model ...
# [124/300] train_loss: 25.948635 valid_loss: 29.779947
# Validation loss decreased (30.003052 --> 29.779947).  Saving model ...
# [125/300] train_loss: 26.370094 valid_loss: 29.317305
# Validation loss decreased (29.779947 --> 29.317305).  Saving model ...
# [126/300] train_loss: 24.527962 valid_loss: 29.019567
# Validation loss decreased (29.317305 --> 29.019567).  Saving model ...
# [127/300] train_loss: 25.843899 valid_loss: 28.699432
# Validation loss decreased (29.019567 --> 28.699432).  Saving model ...
# [128/300] train_loss: 25.487110 valid_loss: 28.792891
# Early Stopping counter: 1 out of 30
# [129/300] train_loss: 24.062769 valid_loss: 28.500769
# Validation loss decreased (28.699432 --> 28.500769).  Saving model ...
# [130/300] train_loss: 24.957470 valid_loss: 27.781380
# Validation loss decreased (28.500769 --> 27.781380).  Saving model ...
# [131/300] train_loss: 23.126730 valid_loss: 27.284994
# Validation loss decreased (27.781380 --> 27.284994).  Saving model ...
# [132/300] train_loss: 24.191345 valid_loss: 26.965168
# Validation loss decreased (27.284994 --> 26.965168).  Saving model ...
# [133/300] train_loss: 22.621611 valid_loss: 26.813747
# Validation loss decreased (26.965168 --> 26.813747).  Saving model ...
# [134/300] train_loss: 22.936327 valid_loss: 26.084923
# Validation loss decreased (26.813747 --> 26.084923).  Saving model ...
# [135/300] train_loss: 22.442984 valid_loss: 25.858259
# Validation loss decreased (26.084923 --> 25.858259).  Saving model ...
# [136/300] train_loss: 22.229494 valid_loss: 25.902832
# Early Stopping counter: 1 out of 30
# [137/300] train_loss: 21.757156 valid_loss: 26.004454
# Early Stopping counter: 2 out of 30
# [138/300] train_loss: 21.789377 valid_loss: 25.857658
# Validation loss decreased (25.858259 --> 25.857658).  Saving model ...
# [139/300] train_loss: 21.747528 valid_loss: 25.508324
# Validation loss decreased (25.857658 --> 25.508324).  Saving model ...
# [140/300] train_loss: 21.727512 valid_loss: 25.438965
# Validation loss decreased (25.508324 --> 25.438965).  Saving model ...
# [141/300] train_loss: 21.558102 valid_loss: 24.992140
# Validation loss decreased (25.438965 --> 24.992140).  Saving model ...
# [142/300] train_loss: 20.812881 valid_loss: 24.561956
# Validation loss decreased (24.992140 --> 24.561956).  Saving model ...
# [143/300] train_loss: 20.370420 valid_loss: 24.347996
# Validation loss decreased (24.561956 --> 24.347996).  Saving model ...
# [144/300] train_loss: 20.944668 valid_loss: 24.294447
# Validation loss decreased (24.347996 --> 24.294447).  Saving model ...
# [145/300] train_loss: 20.871737 valid_loss: 24.543774
# Early Stopping counter: 1 out of 30
# [146/300] train_loss: 19.928284 valid_loss: 24.295290
# Early Stopping counter: 2 out of 30
# [147/300] train_loss: 20.002619 valid_loss: 24.215225
# Validation loss decreased (24.294447 --> 24.215225).  Saving model ...
# [148/300] train_loss: 20.058563 valid_loss: 24.626032
# Early Stopping counter: 1 out of 30
# [149/300] train_loss: 19.435820 valid_loss: 23.652674
# Validation loss decreased (24.215225 --> 23.652674).  Saving model ...
# [150/300] train_loss: 19.090376 valid_loss: 23.274284
# Validation loss decreased (23.652674 --> 23.274284).  Saving model ...
# [151/300] train_loss: 19.317064 valid_loss: 23.510849
# Early Stopping counter: 1 out of 30
# [152/300] train_loss: 19.331371 valid_loss: 22.702600
# Validation loss decreased (23.274284 --> 22.702600).  Saving model ...
# [153/300] train_loss: 19.389004 valid_loss: 22.523069
# Validation loss decreased (22.702600 --> 22.523069).  Saving model ...
# [154/300] train_loss: 19.104235 valid_loss: 22.718903
# Early Stopping counter: 1 out of 30
# [155/300] train_loss: 18.303272 valid_loss: 22.732203
# Early Stopping counter: 2 out of 30
# [156/300] train_loss: 19.107428 valid_loss: 22.276400
# Validation loss decreased (22.523069 --> 22.276400).  Saving model ...
# [157/300] train_loss: 18.663315 valid_loss: 22.226107
# Validation loss decreased (22.276400 --> 22.226107).  Saving model ...
# [158/300] train_loss: 17.903345 valid_loss: 22.653231
# Early Stopping counter: 1 out of 30
# [159/300] train_loss: 18.268446 valid_loss: 21.791265
# Validation loss decreased (22.226107 --> 21.791265).  Saving model ...
# [160/300] train_loss: 18.537912 valid_loss: 21.622593
# Validation loss decreased (21.791265 --> 21.622593).  Saving model ...
# [161/300] train_loss: 17.883678 valid_loss: 22.127985
# Early Stopping counter: 1 out of 30
# [162/300] train_loss: 17.461596 valid_loss: 21.552282
# Validation loss decreased (21.622593 --> 21.552282).  Saving model ...
# [163/300] train_loss: 17.508799 valid_loss: 21.571487
# Early Stopping counter: 1 out of 30
# [164/300] train_loss: 16.933083 valid_loss: 21.767626
# Early Stopping counter: 2 out of 30
# [165/300] train_loss: 17.266909 valid_loss: 21.334560
# Validation loss decreased (21.552282 --> 21.334560).  Saving model ...
# [166/300] train_loss: 16.968306 valid_loss: 21.390434
# Early Stopping counter: 1 out of 30
# [167/300] train_loss: 16.986734 valid_loss: 21.595072
# Early Stopping counter: 2 out of 30
# [168/300] train_loss: 17.150402 valid_loss: 21.022230
# Validation loss decreased (21.334560 --> 21.022230).  Saving model ...
# [169/300] train_loss: 16.798285 valid_loss: 20.842537
# Validation loss decreased (21.022230 --> 20.842537).  Saving model ...
# [170/300] train_loss: 17.314615 valid_loss: 20.954632
# Early Stopping counter: 1 out of 30
# [171/300] train_loss: 17.090195 valid_loss: 20.989286
# Early Stopping counter: 2 out of 30
# [172/300] train_loss: 16.190269 valid_loss: 20.402952
# Validation loss decreased (20.842537 --> 20.402952).  Saving model ...
# [173/300] train_loss: 16.339777 valid_loss: 20.285896
# Validation loss decreased (20.402952 --> 20.285896).  Saving model ...
# [174/300] train_loss: 16.030010 valid_loss: 20.353697
# Early Stopping counter: 1 out of 30
# [175/300] train_loss: 16.079103 valid_loss: 20.258673
# Validation loss decreased (20.285896 --> 20.258673).  Saving model ...
# [176/300] train_loss: 15.541495 valid_loss: 20.171249
# Validation loss decreased (20.258673 --> 20.171249).  Saving model ...
# [177/300] train_loss: 15.920650 valid_loss: 20.606260
# Early Stopping counter: 1 out of 30
# [178/300] train_loss: 15.542469 valid_loss: 20.373394
# Early Stopping counter: 2 out of 30
# [179/300] train_loss: 15.702333 valid_loss: 20.015522
# Validation loss decreased (20.171249 --> 20.015522).  Saving model ...
# [180/300] train_loss: 16.128679 valid_loss: 19.722075
# Validation loss decreased (20.015522 --> 19.722075).  Saving model ...
# [181/300] train_loss: 15.218198 valid_loss: 19.941635
# Early Stopping counter: 1 out of 30
# [182/300] train_loss: 15.143612 valid_loss: 19.302563
# Validation loss decreased (19.722075 --> 19.302563).  Saving model ...
# [183/300] train_loss: 15.714526 valid_loss: 19.413393
# Early Stopping counter: 1 out of 30
# [184/300] train_loss: 15.147022 valid_loss: 19.910675
# Early Stopping counter: 2 out of 30
# [185/300] train_loss: 15.034452 valid_loss: 19.778259
# Early Stopping counter: 3 out of 30
# [186/300] train_loss: 15.239767 valid_loss: 19.242193
# Validation loss decreased (19.302563 --> 19.242193).  Saving model ...
# [187/300] train_loss: 15.560893 valid_loss: 18.915588
# Validation loss decreased (19.242193 --> 18.915588).  Saving model ...
# [188/300] train_loss: 14.055382 valid_loss: 18.906681
# Validation loss decreased (18.915588 --> 18.906681).  Saving model ...
# [189/300] train_loss: 14.499782 valid_loss: 18.851217
# Validation loss decreased (18.906681 --> 18.851217).  Saving model ...
# [190/300] train_loss: 14.456943 valid_loss: 18.971207
# Early Stopping counter: 1 out of 30
# [191/300] train_loss: 14.366712 valid_loss: 19.175678
# Early Stopping counter: 2 out of 30
# [192/300] train_loss: 14.934056 valid_loss: 18.903799
# Early Stopping counter: 3 out of 30
# [193/300] train_loss: 14.498529 valid_loss: 18.731730
# Validation loss decreased (18.851217 --> 18.731730).  Saving model ...
# [194/300] train_loss: 14.148992 valid_loss: 18.157669
# Validation loss decreased (18.731730 --> 18.157669).  Saving model ...
# [195/300] train_loss: 14.722574 valid_loss: 18.014769
# Validation loss decreased (18.157669 --> 18.014769).  Saving model ...
# [196/300] train_loss: 14.452491 valid_loss: 18.292645
# Early Stopping counter: 1 out of 30
# [197/300] train_loss: 14.129187 valid_loss: 18.368429
# Early Stopping counter: 2 out of 30
# [198/300] train_loss: 14.255933 valid_loss: 18.281677
# Early Stopping counter: 3 out of 30
# [199/300] train_loss: 13.742352 valid_loss: 18.475134
# Early Stopping counter: 4 out of 30
# [200/300] train_loss: 13.745740 valid_loss: 18.219723
# Early Stopping counter: 5 out of 30
# [201/300] train_loss: 13.794325 valid_loss: 18.104164
# Early Stopping counter: 6 out of 30
# [202/300] train_loss: 13.188639 valid_loss: 18.682598
# Early Stopping counter: 7 out of 30
# [203/300] train_loss: 13.629806 valid_loss: 18.154791
# Early Stopping counter: 8 out of 30
# [204/300] train_loss: 13.509281 valid_loss: 18.098839
# Early Stopping counter: 9 out of 30
# [205/300] train_loss: 13.229371 valid_loss: 18.472191
# Early Stopping counter: 10 out of 30
# [206/300] train_loss: 13.232759 valid_loss: 17.899591
# Validation loss decreased (18.014769 --> 17.899591).  Saving model ...
# [207/300] train_loss: 13.001543 valid_loss: 17.698042
# Validation loss decreased (17.899591 --> 17.698042).  Saving model ...
# [208/300] train_loss: 13.339777 valid_loss: 18.205645
# Early Stopping counter: 1 out of 30
# [209/300] train_loss: 13.030639 valid_loss: 18.054506
# Early Stopping counter: 2 out of 30
# [210/300] train_loss: 12.634095 valid_loss: 17.596685
# Validation loss decreased (17.698042 --> 17.596685).  Saving model ...
# [211/300] train_loss: 13.411960 valid_loss: 17.643991
# Early Stopping counter: 1 out of 30
# [212/300] train_loss: 12.936016 valid_loss: 18.452070
# Early Stopping counter: 2 out of 30
# [213/300] train_loss: 13.600813 valid_loss: 17.247520
# Validation loss decreased (17.596685 --> 17.247520).  Saving model ...
# [214/300] train_loss: 12.950325 valid_loss: 17.194620
# Validation loss decreased (17.247520 --> 17.194620).  Saving model ...
# [215/300] train_loss: 12.566975 valid_loss: 18.322676
# Early Stopping counter: 1 out of 30
# [216/300] train_loss: 12.852234 valid_loss: 17.302374
# Early Stopping counter: 2 out of 30
# [217/300] train_loss: 13.129648 valid_loss: 16.958321
# Validation loss decreased (17.194620 --> 16.958321).  Saving model ...
# [218/300] train_loss: 12.573458 valid_loss: 17.097990
# Early Stopping counter: 1 out of 30
# [219/300] train_loss: 13.074605 valid_loss: 17.495073
# Early Stopping counter: 2 out of 30
# [220/300] train_loss: 12.636974 valid_loss: 17.077475
# Early Stopping counter: 3 out of 30
# [221/300] train_loss: 11.616929 valid_loss: 17.531418
# Early Stopping counter: 4 out of 30
# [222/300] train_loss: 12.142308 valid_loss: 16.985044
# Early Stopping counter: 5 out of 30
# [223/300] train_loss: 12.173292 valid_loss: 17.789146
# Early Stopping counter: 6 out of 30
# [224/300] train_loss: 11.897226 valid_loss: 17.642944
# Early Stopping counter: 7 out of 30
# [225/300] train_loss: 11.980543 valid_loss: 16.767736
# Validation loss decreased (16.958321 --> 16.767736).  Saving model ...
# [226/300] train_loss: 12.070095 valid_loss: 16.562960
# Validation loss decreased (16.767736 --> 16.562960).  Saving model ...
# [227/300] train_loss: 11.781875 valid_loss: 17.261969
# Early Stopping counter: 1 out of 30
# [228/300] train_loss: 11.716337 valid_loss: 16.403326
# Validation loss decreased (16.562960 --> 16.403326).  Saving model ...
# [229/300] train_loss: 11.712236 valid_loss: 16.221607
# Validation loss decreased (16.403326 --> 16.221607).  Saving model ...
# [230/300] train_loss: 12.115413 valid_loss: 16.974968
# Early Stopping counter: 1 out of 30
# [231/300] train_loss: 11.734824 valid_loss: 16.842672
# Early Stopping counter: 2 out of 30
# [232/300] train_loss: 11.151789 valid_loss: 16.404604
# Early Stopping counter: 3 out of 30
# [233/300] train_loss: 11.754980 valid_loss: 16.555243
# Early Stopping counter: 4 out of 30
# [234/300] train_loss: 11.379345 valid_loss: 16.547709
# Early Stopping counter: 5 out of 30
# [235/300] train_loss: 11.918194 valid_loss: 16.814095
# Early Stopping counter: 6 out of 30
# [236/300] train_loss: 11.416793 valid_loss: 16.724163
# Early Stopping counter: 7 out of 30
# [237/300] train_loss: 11.604866 valid_loss: 16.404379
# Early Stopping counter: 8 out of 30
# [238/300] train_loss: 11.564384 valid_loss: 16.594238
# Early Stopping counter: 9 out of 30
# [239/300] train_loss: 11.529226 valid_loss: 16.094694
# Validation loss decreased (16.221607 --> 16.094694).  Saving model ...
# [240/300] train_loss: 11.109854 valid_loss: 16.459946
# Early Stopping counter: 1 out of 30
# [241/300] train_loss: 11.750529 valid_loss: 16.727722
# Early Stopping counter: 2 out of 30
# [242/300] train_loss: 11.686202 valid_loss: 16.002766
# Validation loss decreased (16.094694 --> 16.002766).  Saving model ...
# [243/300] train_loss: 11.363531 valid_loss: 16.242210
# Early Stopping counter: 1 out of 30
# [244/300] train_loss: 10.552931 valid_loss: 16.757875
# Early Stopping counter: 2 out of 30
# [245/300] train_loss: 11.275908 valid_loss: 16.118607
# Early Stopping counter: 3 out of 30
# [246/300] train_loss: 10.548601 valid_loss: 15.821445
# Validation loss decreased (16.002766 --> 15.821445).  Saving model ...
# [247/300] train_loss: 11.194660 valid_loss: 15.727172
# Validation loss decreased (15.821445 --> 15.727172).  Saving model ...
# [248/300] train_loss: 11.177383 valid_loss: 15.786614
# Early Stopping counter: 1 out of 30
# [249/300] train_loss: 10.865062 valid_loss: 15.617488
# Validation loss decreased (15.727172 --> 15.617488).  Saving model ...
# [250/300] train_loss: 10.893071 valid_loss: 15.636811
# Early Stopping counter: 1 out of 30
# [251/300] train_loss: 10.691989 valid_loss: 15.638125
# Early Stopping counter: 2 out of 30
# [252/300] train_loss: 10.503815 valid_loss: 15.862646
# Early Stopping counter: 3 out of 30
# [253/300] train_loss: 10.930083 valid_loss: 16.074646
# Early Stopping counter: 4 out of 30
# [254/300] train_loss: 10.603444 valid_loss: 16.030300
# Early Stopping counter: 5 out of 30
# [255/300] train_loss: 10.642095 valid_loss: 15.871022
# Early Stopping counter: 6 out of 30
# [256/300] train_loss: 11.159328 valid_loss: 15.998565
# Early Stopping counter: 7 out of 30
# [257/300] train_loss: 10.848730 valid_loss: 15.568034
# Validation loss decreased (15.617488 --> 15.568034).  Saving model ...
# [258/300] train_loss: 10.360679 valid_loss: 15.266994
# Validation loss decreased (15.568034 --> 15.266994).  Saving model ...
# [259/300] train_loss: 10.707493 valid_loss: 15.754169
# Early Stopping counter: 1 out of 30
# [260/300] train_loss: 10.639946 valid_loss: 15.438367
# Early Stopping counter: 2 out of 30
# [261/300] train_loss: 10.833812 valid_loss: 15.579913
# Early Stopping counter: 3 out of 30
# [262/300] train_loss: 10.217138 valid_loss: 15.456036
# Early Stopping counter: 4 out of 30
# [263/300] train_loss: 10.487491 valid_loss: 15.563739
# Early Stopping counter: 5 out of 30
# [264/300] train_loss: 10.268203 valid_loss: 15.384119
# Early Stopping counter: 6 out of 30
# [265/300] train_loss: 10.863781 valid_loss: 15.954845
# Early Stopping counter: 7 out of 30
# [266/300] train_loss: 10.528699 valid_loss: 15.375793
# Early Stopping counter: 8 out of 30
# [267/300] train_loss: 10.670487 valid_loss: 15.288010
# Early Stopping counter: 9 out of 30
# [268/300] train_loss: 10.025954 valid_loss: 15.578801
# Early Stopping counter: 10 out of 30
# [269/300] train_loss: 10.807923 valid_loss: 15.183492
# Validation loss decreased (15.266994 --> 15.183492).  Saving model ...
# [270/300] train_loss: 9.987150 valid_loss: 14.976443
# Validation loss decreased (15.183492 --> 14.976443).  Saving model ...
# [271/300] train_loss: 9.826754 valid_loss: 15.342955
# Early Stopping counter: 1 out of 30
# [272/300] train_loss: 9.564491 valid_loss: 15.415516
# Early Stopping counter: 2 out of 30
# [273/300] train_loss: 10.396645 valid_loss: 15.178724
# Early Stopping counter: 3 out of 30
# [274/300] train_loss: 10.004527 valid_loss: 15.258580
# Early Stopping counter: 4 out of 30
# [275/300] train_loss: 10.024784 valid_loss: 15.279473
# Early Stopping counter: 5 out of 30
# [276/300] train_loss: 9.745433 valid_loss: 15.587739
# Early Stopping counter: 6 out of 30
# [277/300] train_loss: 9.771055 valid_loss: 15.648877
# Early Stopping counter: 7 out of 30
# [278/300] train_loss: 10.045899 valid_loss: 15.326463
# Early Stopping counter: 8 out of 30
# [279/300] train_loss: 10.270663 valid_loss: 15.209938
# Early Stopping counter: 9 out of 30
# [280/300] train_loss: 9.770414 valid_loss: 15.437115
# Early Stopping counter: 10 out of 30
# [281/300] train_loss: 10.047515 valid_loss: 15.177007
# Early Stopping counter: 11 out of 30
# [282/300] train_loss: 9.938265 valid_loss: 15.133201
# Early Stopping counter: 12 out of 30
# [283/300] train_loss: 9.634860 valid_loss: 15.540764
# Early Stopping counter: 13 out of 30
# [284/300] train_loss: 9.844080 valid_loss: 15.538752
# Early Stopping counter: 14 out of 30
# [285/300] train_loss: 10.625087 valid_loss: 15.695215
# Early Stopping counter: 15 out of 30
# [286/300] train_loss: 10.216541 valid_loss: 14.985065
# Early Stopping counter: 16 out of 30
# [287/300] train_loss: 9.776179 valid_loss: 15.129689
# Early Stopping counter: 17 out of 30
# [288/300] train_loss: 9.570723 valid_loss: 15.389439
# Early Stopping counter: 18 out of 30
# [289/300] train_loss: 9.627401 valid_loss: 15.220571
# Early Stopping counter: 19 out of 30
# [290/300] train_loss: 9.545634 valid_loss: 15.373247
# Early Stopping counter: 20 out of 30
# [291/300] train_loss: 9.312589 valid_loss: 15.122077
# Early Stopping counter: 21 out of 30
# [292/300] train_loss: 9.721631 valid_loss: 15.223869
# Early Stopping counter: 22 out of 30
# [293/300] train_loss: 9.648337 valid_loss: 15.329325
# Early Stopping counter: 23 out of 30
# [294/300] train_loss: 9.730166 valid_loss: 14.963397
# Validation loss decreased (14.976443 --> 14.963397).  Saving model ...
# [295/300] train_loss: 9.377211 valid_loss: 15.338075
# Early Stopping counter: 1 out of 30
# [296/300] train_loss: 9.242164 valid_loss: 15.551683
# Early Stopping counter: 2 out of 30
# [297/300] train_loss: 9.388031 valid_loss: 15.322943
# Early Stopping counter: 3 out of 30
# [298/300] train_loss: 10.054045 valid_loss: 15.411135
# Early Stopping counter: 4 out of 30
# [299/300] train_loss: 9.508389 valid_loss: 15.298996
# Early Stopping counter: 5 out of 30
# [300/300] train_loss: 9.470531 valid_loss: 15.487376
# Early Stopping counter: 6 out of 30

# %% [markdown]
# <STEP 6> 학습 결과 표시, 테스트 파일 각도 예측

# %%
def resultShow():                                                               # 학습 완료후 통계자료를 보여줍니다.
  model = NvidiaModel().to(device)                                              # NvidiaModel 의 Summary를 표시합니다.
  summary(model,(3, 66, 200))

  test_dataset = CustomDataset(x_exam_Image, y_exam_Angle)
  test_loader = DataLoader(test_dataset, batch_size=len(x_exam_Image))

  model = NvidiaModel().to(device)
  model.load_state_dict(torch.load(f'_{project}_model_check.pt'))               # 모델 파일
  model.eval()

  y_pred = []
  y_target = []

  with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            print('pred', output.to(device).cpu().numpy())                                                              # GPU Edition
            print('target', target.to(device).cpu().numpy())                                                            #
            for output_data, target_data in zip(output.to(device).cpu().numpy(), target.to(device).cpu().numpy()):      #
              y_pred.append(output_data)
              y_target.append(target_data)

  mse = mean_squared_error(y_target, y_pred)
  r2s = r2_score(y_target, y_pred)
  #-----------------------------------------------------------------------------
  print('\n표준 편차:', f'{mse:.2f}')
  print('회귀 결정 계수:', f'{r2s:.2%}')
  #-----------------------------------------------------------------------------
  fig, axes = plt.subplots(1, len(x_exam_Image), figsize=(30, 2+3))
  xTImg = imgPaths(x_exam_Image)                                                # 파일 이름 앞에 경로(path) 추가
  for x, c in enumerate(xTImg):
    yuv_image = cv2.imread(c, cv2.IMREAD_UNCHANGED)                             # 테스트 이미지 읽기
    bgr_image = cv2.cvtColor(yuv_image, cv2.COLOR_YUV2BGR)                      # YUV 이미지를 BGR 형식으로 변환
    rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)                      # MatPlot Lib 에서 표시되는 RGB 형식으로 변환
    axes[x].imshow(rgb_image)
    t = x_exam_Image[x] +' / E:'+str(int(y_pred[x]))
    axes[x].set_title(t, fontsize=15)
    axes[x].xaxis.set_ticks([])
    axes[x].yaxis.set_ticks([])

if len(x_exam_Image): resultShow()
print("학습 소요 시간:", int(elapsedTime/60), '분', elapsedTime%60, '초' )      # 학습 소요시간 프린트
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 24, 31, 98]           1,824
#                ELU-2           [-1, 24, 31, 98]               0
#             Conv2d-3           [-1, 36, 14, 47]          21,636
#                ELU-4           [-1, 36, 14, 47]               0
#             Conv2d-5            [-1, 48, 5, 22]          43,248
#                ELU-6            [-1, 48, 5, 22]               0
#             Conv2d-7            [-1, 64, 3, 20]          27,712
#                ELU-8            [-1, 64, 3, 20]               0
#            Dropout-9            [-1, 64, 3, 20]               0
#            Conv2d-10            [-1, 64, 1, 18]          36,928
#               ELU-11            [-1, 64, 1, 18]               0
#           Dropout-12                 [-1, 1152]               0
#            Linear-13                  [-1, 100]         115,300
#               ELU-14                  [-1, 100]               0
#            Linear-15                   [-1, 50]           5,050
#               ELU-16                   [-1, 50]               0
#            Linear-17                   [-1, 10]             510
#               ELU-18                   [-1, 10]               0
#            Linear-19                    [-1, 1]              11
# ================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.15
# Forward/backward pass size (MB): 1.67
# Params size (MB): 0.96
# Estimated Total Size (MB): 2.78
# ----------------------------------------------------------------
# pred [[-49.376442  ]
#  [-39.53029   ]
#  [-12.494657  ]
#  [ -0.21157114]
#  [ 10.649612  ]
#  [ 24.899431  ]
#  [ 49.85418   ]]
# target [[-50.]
#  [-43.]
#  [-14.]
#  [ -1.]
#  [ 16.]
#  [ 23.]
#  [ 49.]]
#
# 표준 편차: 6.90
# 회귀 결정 계수: 99.37%
# 학습 소요 시간: 3 분 27 초
# /tmp/ipython-input-1244/1763350081.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   t = x_exam_Image[x] +' / E:'+str(int(y_pred[x]))

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# 이미지 파일이 들어있는 폴더 경로
folder_path = "/content/0926_ympark"   # Colab에 업로드한 경우 경로 지정

# 파일명 패턴 정규식 (예: P0000__+25.png)
pattern = re.compile(r"P(\d{4})__([+-]?\d+)\.png")

data = []

# 폴더 내 모든 파일 탐색
for filename in os.listdir(folder_path):
    match = pattern.match(filename)
    if match:
        seq_num = int(match.group(1))   # 네 자리 숫자
        value = int(match.group(2))     # 부호 포함 정수
        data.append([seq_num, value])

import os
import re
import pandas as pd

# 파일명 패턴 정규식 (예: P0000__+25.png)
pattern = re.compile(r"P(\d{4})__([+-]?\d+)\.png")

data = []

# 폴더 내 모든 파일 탐색
for filename in os.listdir(folder_path):
    match = pattern.match(filename)
    if match:   # <-- 들여쓰기 주의 (for 안에서 4칸 들여쓰기, if 안에서 8칸 들여쓰기)
            seq_num = int(match.group(1))   # 네 자리 숫자
            value = int(match.group(2))     # 부호 포함 정수
            data.append([seq_num, value])

# DataFrame 생성
df = pd.DataFrame(data, columns=["sequence_id", "value"])
df = df.sort_values(by="sequence_id").reset_index(drop=True)

# sequence.csv로 저장
csv_path = folder_path+"/sequence.csv"
df.to_csv(csv_path, index=False, encoding="utf-8")

print("sequence.csv 파일 저장 완료:", csv_path)
print(df.head())  # 일부 미리보기

# 시각화
plt.figure(figsize=(12, 6))
plt.plot(df["sequence_id"], df["value"], marker="", linestyle="-")
plt.title("Sequence Data Visualization")
plt.xlabel("Sequence ID")
plt.ylabel("Value")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()


# 저장
output_img = folder_path+"/sequence_timeseries.png"
plt.savefig(output_img, dpi=300, bbox_inches="tight")
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1244/2469102.py in <cell line: 0>()
#      13
#      14 # 폴더 내 모든 파일 탐색
# ---> 15 for filename in os.listdir(folder_path):
#      16     match = pattern.match(filename)
#      17     if match:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/0926_ympark'

# %%
# value에 대한 히스토그램
plt.figure(figsize=(10,6))
plt.hist(df["value"], bins=50, color="orange", edgecolor="black")
plt.title("Histogram of Value", fontsize=14)
plt.xlabel("Value (-90 ~ +90)")
plt.ylabel("Frequency")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
plt.tight_layout()
plt.show()
